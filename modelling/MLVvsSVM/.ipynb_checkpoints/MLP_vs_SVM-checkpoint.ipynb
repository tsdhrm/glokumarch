# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MLPvsSVM.csv')

# %%
df
# Out:
#   model  test_accuracy  test_precision  test_recall   test_f1
# 0   MLP       0.911765        0.923077     0.857143  0.888889
# 1   SVM       0.823529        0.722222     0.928571  0.812500

# %%
list(df.columns)
# Out:
# ['model', 'test_accuracy', 'test_precision', 'test_recall', 'test_f1']

# %%
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(20,8))

columns = list(df.columns)[1:]
for i in range(0, 4):
    sns.barplot(data=df, x='model', y=columns[i], ax=ax[i])
